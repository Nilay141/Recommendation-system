# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
#textblob -Sentiment Analysis
s="Hello how are you? My name is Nilay patel"
print(word_tokenize(s))
print(sent_tokenize(s))
# Out:
# ['Hello', 'how', 'are', 'you', '?', 'My', 'name', 'is', 'Nilay', 'patel']
# ['Hello how are you?', 'My name is Nilay patel']

# %%
token=word_tokenize(s)
remove_stopwords=[i for i in token if not i in stopwords.words()]

# %%
(" ").join(remove_stopwords)
# Out:
# 'Hello ? My Nilay patel'

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob

# %%
df=pd.read_csv(r"data\cloths-rating.csv")
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text
# 0                        Great taffy at a great price.
# 1    Absolutely wonderful - silky and sexy and comf...
# 2                   Love this dress! it's sooo pretty.
# 3    I had such high hopes for this dress and reall...
# 4    I love, love, love this jumpsuit. it's fun, fl...
# ..                                                 ...
# ...

# %%
s1="Hello how are you? My name is Nilay Nitin Patel"
TextBlob(str(s1)).sentiment.polarity
# Out:
# 0.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=634, step=1)

# %%
df[df.index==2]['Text'].values
# Out:
# array(["Love this dress! it's sooo pretty."], dtype=object)

# %%
df['Updated_Text']=df["Text"]
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text  \
# 0                        Great taffy at a great price.
# 1    Absolutely wonderful - silky and sexy and comf...
# 2                   Love this dress! it's sooo pretty.
# 3    I had such high hopes for this dress and reall...
# 4    I love, love, love this jumpsuit. it's fun, fl...
# ..                                                 ...
# ...

# %%
for i in range(len(df)):
    temp=df[df.index==i]['Text'].values[0]
    token=word_tokenize(temp)
    remove_stopwords=[i for i in token if not i in stopwords.words()]
    df[df.index==i]['Updated_Text'].values[0]=(" ").join(remove_stopwords)

# %%
def sentiment(s):
    try:
        return TextBlob(str(s)).sentiment.polarity
    except:
        return 0

# %%
df['Sentiment']=df['Updated_Text'].apply(sentiment)

# %%
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text  \
# 0                        Great taffy at a great price.
# 1    Absolutely wonderful - silky and sexy and comf...
# 2                   Love this dress! it's sooo pretty.
# 3    I had such high hopes for this dress and reall...
# 4    I love, love, love this jumpsuit. it's fun, fl...
# ..                                                 ...
# ...

# %%
df.isnull().sum()
# Out:
# ProductID       0
# UserID          0
# Rating          0
# Text            0
# Updated_Text    0
# Sentiment       0
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text  \
# 0                        Great taffy at a great price.
# 1    Absolutely wonderful - silky and sexy and comf...
# 2                   Love this dress! it's sooo pretty.
# 3    I had such high hopes for this dress and reall...
# 4    I love, love, love this jumpsuit. it's fun, fl...
# ..                                                 ...
# ...

# %%
df[df['ProductID']==1077].sort_values(by=['Sentiment'],ascending=True)
# Out:
#      ProductID                UserID  Rating  \
# 10        1077  AVph0EeEilAPnD_x9myq       1
# 493       1077  AVqkEM34QMlgsOJE6e8q       1
# 162       1077  AVqVGZN9QMlgsOJE6eUZ       1
# 265       1077            B071VPLC99       1
# 350       1077  AVsRjfwAU2_QcyX9PHqe       1
# 11        1077  AVph0EeEilAPnD_x9myq       3
# 279       1077            B071WRP912       5
# 479       1077  AVqVGZNvQMlgsOJE6eUY       1
# 23        1077  AVpgdkC8ilAPnD_xsvyi       2
# 551       1077            B0832PGNNH       1
# 407       1077  AVpftoij1cnluZ0-p5n2       1
# 413       1077            B07MKNRBFS       4
# 330       1077            B078X5298B       2
# 192       1077  AVphLY7v1cnluZ0-_Ty0       5
# 338       1077            B079TXZ142       5
# 280       1077            B071WRP912       1
# 422       1077            B07MKNRBFS       1
# 484       1077            B07VYRQFBJ       1
# 492       1077            B07VYRQFBJ       5
# 108       1077            B00R60PBTC       1
# ...

# %%
pid=int(input("Enter Product ID: "))
try:
    
    polarity=(df[df['ProductID']==pid]['Sentiment'].mean())
    
    if(polarity>0):
        print("\nGood Product")
    elif(polarity==0):
        print("\nAverage Product")
    elif(polarity<0):
        print("\nNot Good Product to Purchase")
    else:
        print("\nUnable to Fetch Polarity")
            
except:
    None
# Out:
# Enter Product ID: 1077
#
# Good Product

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 634 entries, 0 to 633
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     634 non-null    int64
#  1   UserID        634 non-null    object
#  2   Rating        634 non-null    int64
#  3   Text          634 non-null    object
#  4   Updated_Text  634 non-null    object
#  5   Sentiment     634 non-null    float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 34.7+ KB
